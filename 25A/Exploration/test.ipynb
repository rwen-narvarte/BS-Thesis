# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from scipy.optimize import curve_fit

# %%
DFA_DataF = np.load('DFA_F_results.npy')
DFA_DataN = np.load('DFA_N_results.npy')
DFA_DataO = np.load('DFA_O_results.npy')
DFA_DataS = np.load('DFA_S_results.npy')
DFA_DataZ = np.load('DFA_Z_results.npy')

Hurst_DataF = np.load('DFA_F_Hurst.npy')
Hurst_DataN = np.load('DFA_N_Hurst.npy')
Hurst_DataO = np.load('DFA_O_Hurst.npy')
Hurst_DataS = np.load('DFA_S_Hurst.npy')
Hurst_DataZ = np.load('DFA_Z_Hurst.npy')

Data = [DFA_DataF, DFA_DataN, DFA_DataO, DFA_DataS, DFA_DataZ]
Hurst = [Hurst_DataF, Hurst_DataN, Hurst_DataO, Hurst_DataS, Hurst_DataZ]
Labels = ['F', 'N', 'O', 'S', 'Z']

# %%
plt.boxplot(Hurst, labels=["A", "B", "C", "D", "E"])

plt.title("Boxplot of DFA Values")
plt.ylabel(f"Hurst exponent $(H)$")
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# C:\Users\rjnar\AppData\Local\Temp\ipykernel_19648\2782379220.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(Hurst, labels=["A", "B", "C", "D", "E"])
